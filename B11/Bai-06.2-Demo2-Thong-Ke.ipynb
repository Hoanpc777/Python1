# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
np.set_printoptions(precision=3, suppress=True)

print(pd.__version__)
# Out:
# 1.2.4

# %% [markdown]
# # 1. Ghép nối/trộn các dataframe

# %%
np.random.seed(1)
a1 = pd.DataFrame(np.random.randint(0, 10, size=(10,2)), columns=['C1', 'C2'])
a2 = pd.DataFrame(np.random.randint(0, 10, size=(10,2)), columns=['C3', 'C4'])

# %%
a1
# Out:
#    C1  C2
# 0   5   8
# 1   9   5
# 2   0   0
# 3   1   7
# 4   6   9
# 5   2   4
# 6   5   2
# 7   4   2
# 8   4   7
# 9   7   9

# %%
a2
# Out:
#    C3  C4
# 0   1   7
# 1   0   6
# 2   9   9
# 3   7   6
# 4   9   1
# 5   0   1
# 6   8   8
# 7   3   9
# 8   8   7
# 9   3   6

# %% [markdown]
# ## 1.1. Sử dụng hàm `pd.concat`

# %% [markdown]
# **Ghép theo chiều ngang**

# %%
pd.concat([a1,a2], axis=1)
# Out:
#    C1  C2  C3  C4
# 0   5   8   1   7
# 1   9   5   0   6
# 2   0   0   9   9
# 3   1   7   7   6
# 4   6   9   9   1
# 5   2   4   0   1
# 6   5   2   8   8
# 7   4   2   3   9
# 8   4   7   8   7
# 9   7   9   3   6

# %% [markdown]
# **Ghép theo chiều dọc**
#
# (Tên cột phải giống nhau)

# %%
np.random.seed(2)
a3 = pd.DataFrame(np.random.randint(0, 10, size=(10,2)), columns=['C1', 'C2'])
pd.concat([a1,a3]).reset_index(drop=True)
# Out:
#     C1  C2
# 0    5   8
# 1    9   5
# 2    0   0
# 3    1   7
# 4    6   9
# 5    2   4
# 6    5   2
# 7    4   2
# 8    4   7
# 9    7   9
# 10   8   8
# 11   6   2
# 12   8   7
# 13   2   1
# 14   5   4
# 15   4   5
# 16   7   3
# 17   6   4
# 18   3   7
# 19   6   1

# %% [markdown]
# ## 1.2. Sử dụng hàm `append`
#
# (Ghép theo chiều dọc)

# %%
a1.append(a2, ignore_index=True)
# Out:
#      C1   C2   C3   C4
# 0   5.0  8.0  NaN  NaN
# 1   9.0  5.0  NaN  NaN
# 2   0.0  0.0  NaN  NaN
# 3   1.0  7.0  NaN  NaN
# 4   6.0  9.0  NaN  NaN
# 5   2.0  4.0  NaN  NaN
# 6   5.0  2.0  NaN  NaN
# 7   4.0  2.0  NaN  NaN
# 8   4.0  7.0  NaN  NaN
# 9   7.0  9.0  NaN  NaN
# 10  NaN  NaN  1.0  7.0
# 11  NaN  NaN  0.0  6.0
# 12  NaN  NaN  9.0  9.0
# 13  NaN  NaN  7.0  6.0
# 14  NaN  NaN  9.0  1.0
# 15  NaN  NaN  0.0  1.0
# 16  NaN  NaN  8.0  8.0
# 17  NaN  NaN  3.0  9.0
# 18  NaN  NaN  8.0  7.0
# 19  NaN  NaN  3.0  6.0

# %%
a1.append(a3)
# Out:
#    C1  C2
# 0   5   8
# 1   9   5
# 2   0   0
# 3   1   7
# 4   6   9
# 5   2   4
# 6   5   2
# 7   4   2
# 8   4   7
# 9   7   9
# 0   8   8
# 1   6   2
# 2   8   7
# 3   2   1
# 4   5   4
# 5   4   5
# 6   7   3
# 7   6   4
# 8   3   7
# 9   6   1

# %% [markdown]
# ## 1.3. Sử dụng hàm `join`
#
# (Ghép theo chiều ngang)

# %%
a1.join(a2)
# Out:
#    C1  C2  C3  C4
# 0   5   8   1   7
# 1   9   5   0   6
# 2   0   0   9   9
# 3   1   7   7   6
# 4   6   9   9   1
# 5   2   4   0   1
# 6   5   2   8   8
# 7   4   2   3   9
# 8   4   7   8   7
# 9   7   9   3   6

# %%
# Trùng tên cột?
a1.join(a3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-d8ed69b54364> in <module>
#       1 # Trùng tên cột?
# ----> 2 a1.join(a3)
#
# F:\App\Anaconda\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    8108         5  K5  A5  NaN
#    8109         """
# -> 8110         return self._join_compat(
#    8111             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    8112         )
#
# F:\App\Anaconda\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    8133                     sort=sort,
#    8134                 )
# -> 8135             return merge(
#    8136                 self,
#    8137                 other,
#
# F:\App\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# F:\App\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     684         join_index, left_indexer, right_indexer = self._get_join_info()
#     685
# --> 686         llabels, rlabels = _items_overlap_with_suffix(
#     687             self.left._info_axis, self.right._info_axis, self.suffixes
#     688         )
#
# F:\App\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2176
#    2177     if not lsuffix and not rsuffix:
# -> 2178         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2179
#    2180     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['C1', 'C2'], dtype='object')

# %% [markdown]
# ## 1.4. Sử dụng hàm `merge`
#
# (Theo kiểu SQL)

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "C1": [1, 2]})
right = pd.DataFrame({"key": ["foo", "bar", "ok"], "C2": [4, 5, 6]})
pd.merge(left, right, on="key")
# Out:
#    key  C1  C2
# 0  foo   1   4
# 1  bar   2   5

# %% [markdown]
# **Thử với dữ liệu InstaCart**

# %%
product_order = pd.DataFrame({"product": ["banana", "beer", "milk", "bread"], "ID": [1, 2, 5, 7]})
product_info = pd.DataFrame({"ID": [1,2,3,4,5,6,7], 
                      "Aisle": ["fruits", "liquor", "coffee", "tea", "drink", "vegetables", "food"]})

# %%
product_order
# Out:
#   product  ID
# 0  banana   1
# 1    beer   2
# 2    milk   5
# 3   bread   7

# %%
product_info
# Out:
#    ID       Aisle
# 0   1      fruits
# 1   2      liquor
# 2   3      coffee
# 3   4         tea
# 4   5       drink
# 5   6  vegetables
# 6   7        food

# %%
pd.merge(product_order, product_info, on="ID")
# Out:
#   product  ID   Aisle
# 0  banana   1  fruits
# 1    beer   2  liquor
# 2    milk   5   drink
# 3   bread   7    food

# %% [markdown]
# # 2. Một số hàm thống kê thông dụng

# %% [markdown]
# ## 2.1. Một số thống kê cơ bản

# %%
np.random.seed(1)
a = np.random.randint(20, 25, size=(20,4))
df1 = pd.DataFrame(data=a, index=range(1,21), columns=list('ABCD'), dtype='uint8')
df1.head()
# Out:
#     A   B   C   D
# 1  23  24  20  21
# 2  23  20  20  21
# 3  24  24  21  22
# 4  24  22  24  23
# 5  24  22  24  22

# %%
df1.describe()
# Out:
#                A          B          C          D
# count  20.000000  20.000000  20.000000  20.000000
# mean   22.100000  22.400000  21.250000  21.500000
# std     1.518309   1.535544   1.332785   1.147079
# min    20.000000  20.000000  20.000000  20.000000
# 25%    20.750000  21.000000  20.000000  21.000000
# 50%    22.500000  23.000000  21.000000  21.000000
# 75%    23.000000  24.000000  22.000000  22.000000
# max    24.000000  24.000000  24.000000  24.000000

# %%
df1.min(axis=0)
# Out:
# A    20
# B    20
# C    20
# D    20
# dtype: uint8

# %%
df1.max(axis=0)
# Out:
# A    24
# B    24
# C    24
# D    24
# dtype: uint8

# %%
df1.mean(axis=0)
# Out:
# A    22.10
# B    22.40
# C    21.25
# D    21.50
# dtype: float64

# %%
df1.median(axis=0)
# Out:
# A    22.5
# B    23.0
# C    21.0
# D    21.0
# dtype: float64

# %%
df1.mode(axis='rows')
# df1.mode(axis=0)
# Out:
#       A     B   C     D
# 0  23.0  24.0  20  21.0
# 1   NaN   NaN  21   NaN

# %% [markdown]
# **Lấy ra `n` dòng lớn nhất của một cột nào đó**

# %%
df1.nlargest(5, columns=['A'])
# Out:
#     A   B   C   D
# 3  24  24  21  22
# 4  24  22  24  23
# 5  24  22  24  22
# 6  24  21  21  20
# 1  23  24  20  21

# %%
df1.nlargest(5, columns=['A','C'])
# Out:
#      A   B   C   D
# 4   24  22  24  23
# 5   24  22  24  22
# 3   24  24  21  22
# 6   24  21  21  20
# 16  23  24  23  21

# %% [markdown]
# # 3. Sử dụng hàm value_counts

# %%
df1.value_counts(ascending=False)
# Out:
# A   B   C   D
# 23  24  20  21    2
# 20  23  21  21    1
# 23  20  20  21    1
# 24  22  24  23    1
#             22    1
#     21  21  20    1
# 23  24  23  21    1
#         22  24    1
#     20  20  22    1
# 22  21  23  24    1
# 20  23  21  22    1
# 22  21  20  21    1
#     20  20  21    1
# 21  23  20  20    1
#     21  21  21    1
# 20  24  21  22    1
#             20    1
#     23  22  21    1
# 24  24  21  22    1
# dtype: int64

# %%
df1
# Out:
#      A   B   C   D
# 1   23  24  20  21
# 2   23  20  20  21
# 3   24  24  21  22
# 4   24  22  24  23
# 5   24  22  24  22
# 6   24  21  21  20
# 7   21  21  21  21
# 8   20  24  21  20
# 9   20  23  22  21
# 10  20  23  21  21
# 11  23  24  20  21
# 12  23  24  22  24
# 13  20  23  21  22
# 14  20  24  21  22
# 15  22  21  20  21
# 16  23  24  23  21
# 17  23  20  20  22
# 18  22  21  23  24
# 19  22  20  20  21
# 20  21  23  20  20

# %%
# Sort theo số lượng đã đếm được
df1['A'].value_counts(ascending=True)
# Out:
# 21    2
# 22    3
# 24    4
# 20    5
# 23    6
# Name: A, dtype: int64

# %%
# Sort theo giá trị
df1['A'].value_counts().sort_index(ascending=True)
# Out:
# 20    5
# 21    2
# 22    3
# 23    6
# 24    4
# Name: A, dtype: int64

# %%
# Sort theo số lượng đã đếm được và giá trị
df1['A'].value_counts().sort_values(ascending=True)
# Out:
# 21    2
# 22    3
# 24    4
# 20    5
# 23    6
# Name: A, dtype: int64

# %%
# Đếm theo bins (dành cho dữ liệu số thực hoặc liên tục)
df1['A'].value_counts(bins=3).to_frame().reset_index()
# Out:
#                           index   A
# 0                (22.667, 24.0]  10
# 1  (19.994999999999997, 21.333]   7
# 2              (21.333, 22.667]   3

# %%
df1['A']
# Out:
# 1     23
# 2     23
# 3     24
# 4     24
# 5     24
# 6     24
# 7     21
# 8     20
# 9     20
# 10    20
# 11    23
# 12    23
# 13    20
# 14    20
# 15    22
# 16    23
# 17    23
# 18    22
# 19    22
# 20    21
# Name: A, dtype: uint8

# %%
# Phải tự gán lại tên cột!!!
count_A = df1['A'].value_counts().sort_index(ascending=True).reset_index()
count_A
# Out:
#    index  A
# 0     20  5
# 1     21  2
# 2     22  3
# 3     23  6
# 4     24  4

# %%
count_A.keys()
# Out:
# Index(['index', 'A'], dtype='object')

# %%
count_A.columns
# Out:
# Index(['index', 'A'], dtype='object')

# %%
count_A.columns = ['Unique_A', 'counts']
count_A
# Out:
#    Unique_A  counts
# 0        20       5
# 1        21       2
# 2        22       3
# 3        23       6
# 4        24       4

# %% [markdown]
# # 4. Groupby

# %%
df1.groupby(['A'])

# %%
# Các groups được lưu thành dict, 
# - Mỗi key là 1 group
# - Mỗi value là 1 list các index của group đó
df1.groupby(['A']).groups
# Out:
# {20: [8, 9, 10, 13, 14], 21: [7, 20], 22: [15, 18, 19], 23: [1, 2, 11, 12, 16, 17], 24: [3, 4, 5, 6]}

# %%
df1.groupby(['A']).groups[21]
# Out:
# Int64Index([7, 20], dtype='int64')

# %% [markdown]
# **Lấy ra một group**

# %%
df1.groupby(['A'], sort=True, dropna=True).get_group(20)
# Out:
#      A   B   C   D
# 8   20  24  21  20
# 9   20  23  22  21
# 10  20  23  21  21
# 13  20  23  21  22
# 14  20  24  21  22

# %%
df1.loc[df1.groupby(['A']).groups[20]]
# Out:
#      A   B   C   D
# 8   20  24  21  20
# 9   20  23  22  21
# 10  20  23  21  21
# 13  20  23  21  22
# 14  20  24  21  22

# %%
df1
# Out:
#      A   B   C   D
# 1   23  24  20  21
# 2   23  20  20  21
# 3   24  24  21  22
# 4   24  22  24  23
# 5   24  22  24  22
# 6   24  21  21  20
# 7   21  21  21  21
# 8   20  24  21  20
# 9   20  23  22  21
# 10  20  23  21  21
# 11  23  24  20  21
# 12  23  24  22  24
# 13  20  23  21  22
# 14  20  24  21  22
# 15  22  21  20  21
# 16  23  24  23  21
# 17  23  20  20  22
# 18  22  21  23  24
# 19  22  20  20  21
# 20  21  23  20  20

# %% [markdown]
# **Kết hợp với các hàm khác: `sum`, `mean`,...**

# %%
df1.groupby(['A']).sum()
# Out:
#       B    C    D
# A
# 20  117  106  106
# 21   44   41   41
# 22   62   63   66
# 23  136  125  130
# 24   89   90   87

# %%
df1.groupby(['A']).mean()
# Out:
#             B          C          D
# A
# 20  23.400000  21.200000  21.200000
# 21  22.000000  20.500000  20.500000
# 22  20.666667  21.000000  22.000000
# 23  22.666667  20.833333  21.666667
# 24  22.250000  22.500000  21.750000

# %%
df1.groupby(['A']).get_group(20)
# Out:
#      A   B   C   D
# 8   20  24  21  20
# 9   20  23  22  21
# 10  20  23  21  21
# 13  20  23  21  22
# 14  20  24  21  22

# %%
df1.groupby(['A']).count()
# Out:
#     B  C  D
# A
# 20  5  5  5
# 21  2  2  2
# 22  3  3  3
# 23  6  6  6
# 24  4  4  4

# %%
df1.groupby(['A'])['B'].value_counts()
# Out:
# A   B
# 20  23    3
#     24    2
# 21  21    1
#     23    1
# 22  21    2
#     20    1
# 23  24    4
#     20    2
# 24  22    2
#     21    1
#     24    1
# Name: B, dtype: int64

# %%
df1.groupby(['A', 'B']).sum()
# Out:
#         C   D
# A  B
# 20 23  64  64
#    24  42  42
# 21 21  21  21
#    23  20  20
# 22 20  20  21
#    21  43  45
# 23 20  40  43
#    24  85  87
# 24 21  21  20
#    22  48  45
#    24  21  22

# %% [markdown]
# ## Ví dụ: sử dụng Groupby với danh sách sản phẩm của 2 chi nhánh

# %%
cn1 = pd.Series(['banana', 'beer', 'bread', 'milk', 'milk', 'beer'], name='product')
cn1
# Out:
# 0    banana
# 1      beer
# 2     bread
# 3      milk
# 4      milk
# 5      beer
# Name: product, dtype: object

# %%
cn2 = pd.Series(['banana', 'bread', 'bread', 'milk', 'milk', 'milk'], name='product')
cn2
# Out:
# 0    banana
# 1     bread
# 2     bread
# 3      milk
# 4      milk
# 5      milk
# Name: product, dtype: object

# %% [markdown]
# **Thông tin về sp của từng chi nhánh**

# %%
cn1_count = cn1.value_counts().reset_index()
cn1_count.columns = ['product', 'count']
cn1_count
# Out:
#   product  count
# 0    milk      2
# 1    beer      2
# 2   bread      1
# 3  banana      1

# %%
cn2_count = cn2.value_counts().reset_index()
cn2_count.columns = ['product', 'count']
cn2_count
# Out:
#   product  count
# 0    milk      3
# 1   bread      2
# 2  banana      1

# %% [markdown]
# **Tổng hợp lại**

# %%
tonghop = pd.concat([cn1_count, cn2_count])
tonghop
# Out:
#   product  count
# 0    milk      2
# 1    beer      2
# 2   bread      1
# 3  banana      1
# 0    milk      3
# 1   bread      2
# 2  banana      1

# %%
tonghop.groupby(['product']).sum().reset_index()
# Out:
#   product  count
# 0  banana      2
# 1    beer      2
# 2   bread      3
# 3    milk      5
