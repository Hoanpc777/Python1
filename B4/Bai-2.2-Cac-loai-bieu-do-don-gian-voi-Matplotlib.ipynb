# %% [markdown]
# ![alt text](Figure2.jpg)

# %% [markdown]
# # 0. Cập nhật phiên bản mới cho matplotlib

# %%
# %pip install --upgrade matplotlib

# %%
import matplotlib
from matplotlib import pyplot as plt
print(matplotlib.__version__)
# Out:
# 3.4.3

# %% [markdown]
# **Ôn tập**

# %%
import matplotlib.colors as colors
color_list = list(colors._colors_full_map.keys())
# color_list = list(colors._colors_full_map.values())
print(color_list)
# Out:
# ['xkcd:cloudy blue', 'xkcd:dark pastel green', 'xkcd:dust', 'xkcd:electric lime', 'xkcd:fresh green', 'xkcd:light eggplant', 'xkcd:nasty green', 'xkcd:really light blue', 'xkcd:tea', 'xkcd:warm purple', 'xkcd:yellowish tan', 'xkcd:cement', 'xkcd:dark grass green', 'xkcd:dusty teal', 'xkcd:grey teal', 'xkcd:macaroni and cheese', 'xkcd:pinkish tan', 'xkcd:spruce', 'xkcd:strong blue', 'xkcd:toxic green', 'xkcd:windows blue', 'xkcd:blue blue', 'xkcd:blue with a hint of purple', 'xkcd:booger', 'xkcd:bright sea green', 'xkcd:dark green blue', 'xkcd:deep turquoise', 'xkcd:green teal', 'xkcd:strong pink', 'xkcd:bland', 'xkcd:deep aqua', 'xkcd:lavender pink', 'xkcd:light moss green', 'xkcd:light seafoam green', 'xkcd:olive yellow', 'xkcd:pig pink', 'xkcd:deep lilac', 'xkcd:desert', 'xkcd:dusty lavender', 'xkcd:purpley grey', 'xkcd:purply', 'xkcd:candy pink', 'xkcd:light pastel green', 'xkcd:boring green', 'xkcd:kiwi green', 'xkcd:light grey green', 'xkcd:orange pink', 'xkcd:tea green', 'xkcd:very light brown', 'xkcd:egg shell', 'xkcd:eggplant purple', 'xkcd:powder pink', 'xkcd:reddish grey', 'xkcd:baby shit brown', 'xkcd:liliac', 'xkcd:stormy blue', 'xkcd:ugly brown', 'xkcd:custard', 'xkcd:darkish pink', 'xkcd:deep brown', 'xkcd:greenish beige', 'xkcd:manilla', 'xkcd:off blue', 'xkcd:battleship grey', 'xkcd:browny green', 'xkcd:bruise', 'xkcd:kelley green', 'xkcd:sickly yellow', 'xkcd:sunny yellow', 'xkcd:azul', 'xkcd:darkgreen', 'xkcd:green/yellow', 'xkcd:lichen', 'xkcd:light light green', 'xkcd:pale gold', 'xkcd:sun yellow', 'xkcd:tan green', 'xkcd:burple', 'xkcd:butterscotch', 'xkcd:toupe', 'xkcd:dark cream', 'xkcd:indian red', 'xkcd:light lavendar', 'xkcd:poison green', 'xkcd:baby puke green', 'xkcd:bright yellow green', 'xkcd:charcoal grey', 'xkcd:squash', 'xkcd:cinnamon', 'xkcd:light pea green', 'xkcd:radioactive green', 'xkcd:raw sienna', 'xkcd:baby purple', 'xkcd:cocoa', 'xkcd:light royal blue', 'xkcd:orangeish', 'xkcd:rust brown', 'xkcd:sand brown', 'xkcd:swamp', 'xkcd:tealish green', 'xkcd:burnt siena', 'xkcd:camo', 'xkcd:dusk blue', 'xkcd:fern', 'xkcd:old rose', 'xkcd:pale light green', 'xkcd:peachy pink', 'xkcd:rosy pink', 'xkcd:light bluish green', 'xkcd:light bright green', 'xkcd:light neon green', 'xkcd:light seafoam', 'xkcd:tiffany blue', 'xkcd:washed out green', 'xkcd:browny orange', 'xkcd:nice blue', 'xkcd:sapphire', 'xkcd:greyish teal', 'xkcd:orangey yellow', 'xkcd:parchment', 'xkcd:straw', 'xkcd:very dark brown', 'xkcd:terracota', 'xkcd:ugly blue', 'xkcd:clear blue', 'xkcd:creme', 'xkcd:foam green', 'xkcd:grey/green', 'xkcd:light gold', 'xkcd:seafoam blue', 'xkcd:topaz', 'xkcd:violet pink', 'xkcd:wintergreen', 'xkcd:yellow tan', 'xkcd:dark fuchsia', 'xkcd:indigo blue', 'xkcd:light yellowish green', 'xkcd:pale magenta', 'xkcd:rich purple', 'xkcd:sunflower yellow', 'xkcd:green/blue', 'xkcd:leather', 'xkcd:racing green', 'xkcd:vivid purple', 'xkcd:dark royal blue', 'xkcd:hazel', 'xkcd:muted pink', 'xkcd:booger green', 'xkcd:canary', 'xkcd:cool grey', 'xkcd:dark taupe', 'xkcd:darkish purple', 'xkcd:true green', 'xkcd:coral pink', 'xkcd:dark sage', 'xkcd:dark slate blue', 'xkcd:flat blue', 'xkcd:mushroom', 'xkcd:rich blue', 'xkcd:dirty purple', 'xkcd:greenblue', 'xkcd:icky green', 'xkcd:light khaki', 'xkcd:warm blue', 'xkcd:dark hot pink', 'xkcd:deep sea blue', 'xkcd:carmine', 'xkcd:dark yellow green', 'xkcd:pale peach', 'xkcd:plum purple', 'xkcd:golden rod', 'xkcd:neon red', 'xkcd:old pink', 'xkcd:very pale blue', 'xkcd:blood orange', 'xkcd:grapefruit', 'xkcd:sand yellow', 'xkcd:clay brown', 'xkcd:dark blue grey', 'xkcd:flat green', 'xkcd:light green blue', 'xkcd:warm pink', 'xkcd:dodger blue', 'xkcd:gross green', 'xkcd:ice', 'xkcd:metallic blue', 'xkcd:pale salmon', 'xkcd:sap green', 'xkcd:algae', 'xkcd:bluey grey', 'xkcd:greeny grey', 'xkcd:highlighter green', 'xkcd:light light blue', 'xkcd:light mint', 'xkcd:raw umber', 'xkcd:vivid blue', 'xkcd:deep lavender', 'xkcd:dull teal', 'xkcd:light greenish blue', 'xkcd:mud g ...

# %%
import numpy as np
np.random.seed(10)
X = np.random.randint(0,10, size=(6,10))

# %%
fig,axes = plt.subplots(2, 3, figsize=(8,5), constrained_layout=True)
k=0
for i in range(2):
    for j in range(3):
        axes[i][j].plot(X[k], color=color_list[k])
        k += 1
plt.show()

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot()

for i in range(6):
    ax.plot(X[i], color=color_list[i])

plt.show()

# %% [markdown]
# **Thiết lập font cho nhãn**

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot()

for i in range(6):
    ax.plot(X[i], color=color_list[i])

# Font của các tiêu đề
ax.set_title("Biểu Đồ Ví Dụ", 
             loc='left',          # Các vị trí: left | center | right
             fontstyle='oblique', # Các style: normal | italic |  oblique
             weight='bold', fontsize=14, 
            )
ax.set_ylabel("Giá trị trục y", weight='bold', fontsize=12)
ax.set_xlabel("Giá trị trục x", weight='bold', fontsize=12)

# Font của các trục
ax.set_xticks(range(10))
ax.set_xticklabels(range(1,11), fontsize=15, weight='bold')

plt.show()

# %% [markdown]
# ## 1. Biểu đồ cột: bar()

# %%
ds = [20,22,23,25,27,34, 23, 21, 19, 24, 25, 27, 29, 28, 26, 29, 25, 24,20,22,23,25,27]

plt.bar(x=range(len(ds)),height=ds)
plt.show()

# %%
# Biểu đồ cột với giá trị âm
# Đồng thời thử đổi màu của đường viền quanh cột với edgecolor
ds = [20,-22,23,25,-27,34, 23, -21, 19, 24, 25, 27, -29, 28, 26, 29, -25, 24,20,22,23,25,27]

plt.bar(x=range(len(ds)), edgecolor = "k", linewidth=2, height=ds)
plt.show()

# %%
# 2 Biểu đồ cột với scale khác nhau

ds1 = [20, 22, 23, 25, 27, 34, 23, 21, 19, 20]
ds2 = [24, 25, 24, 21, 22, 26, 18, 25, 24, 27]

# %%
# Tạo nhanh subplot từ plt (thay vì fig.add_subplot)
ax1 = plt.subplot(1,2,1)
plt.bar(x=range(len(ds1)),height=ds1, color="red")

ax2 = plt.subplot(1,2,2)
plt.bar(x=range(len(ds2)),height=ds2, color="green")
plt.show()

# %%
# Chỉnh lại scale bằng tham số sharey
fig = plt.figure()
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2, sharey=ax1)

ax1.bar(x=range(len(ds1)),height=ds1, color="red")
ax2.bar(x=range(len(ds2)),height=ds2, color="green")

plt.show()

# %%
# Chỉnh vị trí in xtick_label
fig = plt.figure()
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2, sharey=ax1)

x1 = range(len(ds1))
ax1.bar(x=x1, height=ds1, color="red", align="center")
ax1.set_xticks(x1)

x2 = range(len(ds2))
ax2.bar(x=x2,height=ds2, color="green")

plt.show()

# %%
# Biểu đồ dạng nhóm (group) với 2 giá trị
plt.bar(x=[i-0.2 for i in x1], height=ds1, width=0.4, color="red", label="Nam")
plt.bar(x=[i+0.2 for i in x2], height=ds2, width=0.4, color="green", label="Nữ")
plt.legend()
plt.show()

# %%
# Biểu đồ dạng chồng lên nhau: 
# set giá trị cho tham số bottom ở thông số thứ 2
plt.bar(x=x1, height=ds1, width=0.4, color="red", label="Nam")
plt.bar(x=x1, height=ds2, width=0.4, color="green", label="Nữ", bottom=ds1)
plt.legend()
plt.show()

# %%
# Thêm số biểu diễn giá trị thành phần
plt.bar(x=x1, height=ds1, width=0.4, color="red", label="Nam")
plt.bar(x=x1, height=ds2, width=0.4, color="green", label="Nữ", bottom=ds1)

# Lưu ý: hiển thị tổng 
ax = plt.gca()
ax.bar_label(container = ax.containers[0], padding=-12)
ax.bar_label(container = ax.containers[1], padding=-12)
#ax.bar_label(container = ax.containers[2], padding=-12)

plt.legend()
plt.show()

# %%
# Thêm số biểu diễn giá trị thành phần
plt.bar(x=x1, height=ds1, width=0.4, color="red", label="Nam")
plt.bar(x=x1, height=ds2, width=0.4, color="green", label="Nữ", bottom=ds1)

ax = plt.gca()

# Các thành phần
ax.bar_label(container = ax.containers[0], padding=-12, label_type='center')
ax.bar_label(container = ax.containers[1], padding=-12, label_type='center')

# Tổng
ax.bar_label(container = ax.containers[1], padding=0, label_type='edge')

plt.legend()
plt.show()

# %%
# Biểu đồ nằm ngang
plt.barh(y=[i-0.2 for i in x1], width=ds1, height=0.4, color="red", label="Nam")
plt.barh(y=[i+0.2 for i in x2], width=ds2, height=0.4, color="green", label="Nữ")
plt.legend(loc='lower right')
plt.show()

# %%
# Biểu đồ nằm ngang dạng nối tiếp nhau:
# set giá trị cho tham số "left"
plt.barh(y=x1, width=ds1, height=0.6, color="red", label="Nam")
plt.barh(y=x1, width=ds2, height=0.4, color="green", left=ds1, label="Nữ")
plt.legend(loc='lower right')
plt.show()

# %%
# Biểu đồ nhóm với 3 tham số
import numpy as np
  
ind = np.array([1,2,3]) 
width = 0.25
  
x = [8, 9, 2]
bar1 = plt.bar(ind, x, width, color = 'r')
  
y = [10, 20, 30]
bar2 = plt.bar(ind+width, y, width, color='g')
  
z = [11, 12, 13]
bar3 = plt.bar(ind+width*2, z, width, color = 'b')
  
plt.xlabel("Dates")
plt.ylabel('Scores')

# Sử dụng xticks để set vị trí của nhãn minh họa
plt.xticks(ind+width,['2021Feb01', '2021Feb02', '2021Feb03'])
plt.legend((bar1, bar2, bar3), ('Player1', 'Player2', 'Player3') )
plt.show()

# %%
# Thêm số biểu thị thông tin từng cột
bar1 = plt.bar(ind, x, width, color = 'r')
bar2 = plt.bar(ind+width, y, width, color='g')
bar3 = plt.bar(ind+width*2, z, width, color = 'b')
  
plt.xlabel("Dates", fontsize=14, weight='bold')
plt.ylabel('Scores', fontsize=14, weight='bold')

ax = plt.gca()
ax.bar_label(container = ax.containers[0], padding=0, label_type='center')
ax.bar_label(container = ax.containers[1], padding=0, label_type='center')

# Chỉnh sử font của cột thứ 3
ax.bar_label(container = ax.containers[2], padding=0, label_type='center', 
             color='w', fontsize=12, weight='bold')

# Sử dụng xticks để set vị trí của nhãn minh họa
plt.xticks(ind+width,['2021Feb01', '2021Feb02', '2021Feb03'])
plt.legend((bar1, bar2, bar3), ('Player1', 'Player2', 'Player3') )
plt.show()

# %% [markdown]
# ## Biểu đồ stem (tương tự biểu đồ cột)

# %%
x = [2,8,9]
y1 = [10, 20, 30]
plt.stem(x,y1, linefmt='--', markerfmt="D", bottom=1)
plt.show()
# stem([x,] y, linefmt=None, markerfmt=None, basefmt=None)

# %%
y2 = [15, -20, -30]
plt.stem(x,y1, linefmt='-.', markerfmt="o", bottom=1)
plt.stem([i+0.2 for i in x], y2, linefmt='--', markerfmt="D", bottom=1)
plt.show()
# stem([x,] y, linefmt=None, markerfmt=None, basefmt=None)

# %% [markdown]
# ## 2. Biểu đồ histogram

# %%
a = [22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]

# %%
# Histogram với bins tự xác định
fig,ax = plt.subplots()
ax.hist(a)
plt.show()

# %%
# Histogram với bins tự xác định
fig,ax = plt.subplots(1,1)
ax.hist(a, bins = [0,25,50,75,100])
ax.set_xticks([0,25,50,75,100])
plt.show()

# %%
# Thử vẽ một phân bố đều
import numpy as np

x = np.random.normal(170, 10, 1000)
plt.hist(x)
plt.show()

# %%
# Tăng số lượng bins để hiển thị chi tiết hơn
plt.hist(x, bins=20)
plt.grid()
plt.show()

# %%
# Chỉnh sửa màu và độ mờ, hướng ngang
plt.hist(x, bins=20, color='red', alpha=0.75, orientation="horizontal")
plt.grid()
plt.show()

# %%
# chỉnh sửa chiều rộng của cột hiển thị
# width/rwidth
plt.hist(x, bins=10, rwidth=0.75, facecolor='red', alpha=0.75)
plt.show()

# %%
# Xác định vị trí in xtick_labels ở chính giữa cột
bins = 140+np.arange(10)*7

plt.hist(x, bins=bins, width=6, facecolor='red', alpha=0.75)
plt.xticks(bins)
plt.show()

# %%
# So sánh phân bố của vài dữ liệu khác nhau
colors = np.random.randint(100, size=(20))

x = np.random.normal(170, 10, 10000)
plt.hist(x, bins=50, facecolor='red', density=True, alpha=0.75)

x = np.random.normal(155, 20, 10000)
plt.hist(x, bins=50, facecolor='blue', density=True, alpha=0.75)

plt.legend(["Nam", "Nữ"])
plt.grid()
plt.show()

# %% [markdown]
# ## 3. Biểu đồ scatter

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,76,103,87,94,78,77,85,86]

# %%
plt.scatter(x, y)
plt.show()

# %%
# Vẽ scatter cho 2 quan sát dữ liệu khác nhau
plt.scatter(x, y)

x2 = [2,2,8,1,15,8,12,9,7,3,11,4,7,14,12]
y2 = [100,105,84,105,90,99,90,95,94,100,79,112,91,80,85]
plt.scatter(x2, y2)

plt.show()

# %%
# Biểu diễn scatter với các màu và kích thước khác nhau
colors=["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"]
sizes=[50, 80, 90, 30, 20, 100, 150, 40, 60, 70, 50, 90, 70]
plt.scatter(x, y, color=colors, sizes=sizes)
plt.show()

# %%
# Sử dụng thêm colorbar
plt.scatter(x, y, c=colors, sizes=sizes)
plt.colorbar()
plt.show()

# %%
# Thử biểu diễn nhiều màu sắc
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()

plt.show()

# %%
# Biểu đồ scatter phức hợp
fig, ax = plt.subplots()

x1 = np.random.normal(170, 10, 100)
y1 = np.random.normal(120, 10, 100)
ax.scatter(x1, y1, c='red')

x2 = np.random.normal(70, 10, 100)
y2 = np.random.normal(20, 10, 100)
ax.scatter(x2, y2, c='green')

x3 = np.random.normal(70, 10, 100)
y3 = np.random.normal(120, 10, 100)
ax.scatter(x3, y3, c='blue')

plt.show()

# %% [markdown]
# ## 4. Biểu đồ area

# %%
# Sử dụng stackplot 
x = [1, 2, 3, 4, 5]
y1 = [1, 1, 2, 3, 5]
y2 = [0, 4, 2, 6, 8]
y3 = [1, 3, 5, 7, 9]

labels = ["Fibonacci ", "Evens", "Odds"]

# %%
plt.stackplot(x, y1, y2, y3, labels=labels, baseline='zero')
plt.legend(loc='upper left')
plt.show()

# %%
# Sử dụng fill_between
y2_new = [a+b for a,b in zip(y2,y1)]
y3_new = [a+b+c for a,b,c in zip(y3,y2,y1)]

plt.plot(x,y1)
plt.plot(x,y2_new)
plt.plot(x,y3_new)
plt.legend(loc='upper left', labels=labels)

plt.fill_between(x, y1, 0)
plt.fill_between(x, y2_new, y1)
plt.fill_between(x, y3_new, y2_new)

plt.show()

# %% [markdown]
# **Sử dụng stackplot với baseline khác**

# %%
plt.stackplot(x, y1, y2, y3, labels=labels, baseline='wiggle')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## 5. Biểu đồ hình tròn

# %%
y = [35, 25, 25, 15]
plt.pie(y)
plt.show()

# %%
# Hiển thị số phần trăm
y = [35, 25, 25, 50]
plt.pie(y, autopct='%1.1f%%')
plt.show()

# %%
# Thêm trang trí: 
# 1. cho một mảnh nhô ra
# 2. Thay đổi góc bắt đầu

# Thứ tự ngược chiều kim đồng hồ, bắt đầu từ vị trí 3h (0 độ):
labels = 'Trà-Cà Phê', 'Nước Trái Cây', 'SP Sữa', 'Khác'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)
colors = 'brown', 'green', 'pink', 'yellow'

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        #colors=colors, 
        shadow=True, startangle=90, )
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# Sử dụng legend thay vì nhãn
plt.pie(sizes, explode=explode, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=90, )
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.legend(labels, loc="best")
plt.show()

# %%
# Lấy ra patch để tiến hành xử lý thêm
# (Cho patch "SP Sữa" mờ đi)

kq = plt.pie(sizes, explode=explode, autopct='%1.1f%%',
             shadow=True, startangle=90, )

patches, texts, autotexts = kq
patches[2].set_alpha(0.25)

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.legend(labels, loc="best")
plt.show()

# %% [markdown]
# ## 6. Biểu đồ dạng Tree-map
# **Lưu ý:** Cần phải cài module squarify vào Ananconda

# %%
# Cách cài đặt module squarify
# (Chạy câu lệnh command line ngay trên Jupyter Notebook)
# %pip install squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# Cách khác
# !pip install squarify

# %% [markdown]
# **Giả sử ta có dữ liệu về doanh thu theo mặt hàng như sau:**

# %%
volume = [1783, 1221, 1097, 839, 736, #493,
          472, 150, 105, 66, 50]
labels = ['Water\n volume: 1783k',
          'Coffe\n volume: 1221k',
          'Yogurt\n volume: 1097k',
          'Chocolate\n volume: 839k',
          'Juice\n volume: 736k',
          'Snacking\n volume: 493k',
          'Fruit\n volume: 472k',
          #'Beef\n volume: 150k',
          'Ice-cream\n volume: 105k',
          'Salad\n volume: 66k',
          'Shampooing\n volume: 50k']
color_list = ['#0f7216', '#b2790c', '#ffe9a3',
              '#f9d4d4', '#d35158', '#ea3033']

# %%
# Sử dụng hàm squarify.plot()
import squarify
plt.rc('font', size=8)

fig = plt.figure(figsize=(10,5))

squarify.plot(sizes=volume, label=labels,
              color=color_list, alpha=0.7)

plt.axis("off")
plt.show()

# %% [markdown]
# **Vẽ biểu đồ squarify trên subplots**

# %%
fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(2, 1, 1)
squarify.plot(sizes=volume, label=labels,
              pad=True,
              color=color_list, alpha=0.7)
plt.axis("off")

ax2 = fig.add_subplot(2, 2, 3)
ax3 = fig.add_subplot(2, 2, 4)

ds1 = [20, 22, 23, 25, 27, 34, 23, 21, 19, 20]
ds2 = [24, 25, 24, 21, 22, 26, 18, 25, 24, 27]
ax2.bar(x=range(len(ds1)), height=ds1, color="red", align="center")
ax3.bar(x=range(len(ds2)), height=ds2, color="green")

plt.show()
