# %% [markdown]
# 1.1. Chỉ lấy các phần tử ở vị trí chẵn trong chuỗi (0,2,4,6...,20)

# %%
#Create a new list
ls = []
ls1 = []
#Create even list
for i in range(0,21):
    if i%2 ==0:
        ls.append(i)
#Create a list that has even index
for i,j in enumerate(ls,1):
    if i%2==0:
        ls1.append(j)
print(ls1)
# Out:
# [2, 6, 10, 14, 18]

# %% [markdown]
# 1.2. Chỉ lấy các phần tử ở vị trí lẻ trong chuỗi (1,3,5...,19)

# %%
#Create a new list
ls = []
ls1 = []
#Create odd list
for i in range(0,21):
    if i%2 ==1:
        ls.append(i)
#Create a list that has odd index
for i,j in enumerate(ls,1):
    if i%2==1:
        ls1.append(j)
print(ls1)
# Out:
# [1, 5, 9, 13, 17]

# %% [markdown]
# 2. Thực hiện lại các bài tập trong bài trước và lưu kết quả vào file text

# %% [markdown]
# 3.1. Đọc file “example_bai_1.2.csv” và tính tần số & tần suất khách hàng mua ở Tp HCM, Hà Nội, Đà Nẵng

# %%
#Check directory
# %pwd
#import module
import csv, os
cwd = os.chdir(r'C:\Users\Hoanpc.TSTDESK01\Desktop\Python\Bai-01.2-Lap-trinh-Python-Co-ban-Demo')
# csv file name
filename = "example_bai_1.2.csv"
# initializing the titles and rows list
title, rows, area, area_1 = [],[],[],[]
KV1,KV2,KV3 = 0,0,0
with open(filename, 'r',encoding="utf8") as f:
    #creating a csv reader obj
    csvreader = csv.reader(f)
    # extracting field names through first row
    title = next(csvreader)
    # extracting each data row one by one
    for row in csvreader:
        rows.append(row)
for i in rows:
    j = [i[0]]
    area.append(j)
for i in area:
    if i not in area_1:
        area_1.append(i)
for i in area:
    if i == area_1[0]: KV1+=1
    if i == area_1[1]: KV2+=1
    if i == area_1[2]: KV3+=1
Total = len(area)
pct1 = KV1/Total*100
pct2 = KV2/Total*100
pct3 = KV3/Total*100
print(f'Khu vực người {area_1[0][0]} là {KV1} người, tỷ lệ là {pct1:.2f}%')
print(f'Khu vực người {area_1[1][0]} là {KV2} người, tỷ lệ là {pct2:.2f}%')
print(f'Khu vực người {area_1[2][0]} là {KV3} người, tỷ lệ là {pct3:.2f}%')
# Out:
# Khu vực người Hà Nội là 274 người, tỷ lệ là 27.40%
# Khu vực người TP HCM là 490 người, tỷ lệ là 49.00%
# Khu vực người Đà Nẵng là 236 người, tỷ lệ là 23.60%

# %% [markdown]
# 3.2. Đọc file “example_bai_1.2.csv” và tính tần số & tần suất khách hàng mua là Nam/Nữ

# %%
sex, sex_1, SL1, SL2= [],[],0,0
for i in rows:
    j = [i[1]]
    sex.append(j)
for i in sex:
    if i not in sex_1:
        sex_1.append(i)
for i in sex:
    if i == sex_1[0]: SL1+=1
    if i == sex_1[1]: SL2+=1
S1 = SL1/Total*100
S2 = SL2/Total*100
print(f'Số {sex_1[0]} là {SL1}, tỷ lệ là {S1:.2f}%')
print(f'Số {sex_1[1]} là {SL2}, tỷ lệ là {S2:.2f}%')
# Out:
# Số ['Nữ'] là 501, tỷ lệ là 50.10%
# Số ['Nam'] là 499, tỷ lệ là 49.90%

# %% [markdown]
# 3.3.Đọc file “example_bai_1.2.csv” và tính mean, median của Tổng đơn và Rating

# %%
tong_don,tong_don_1, gt = [],[],0
for i in rows:
    j = [i[2]]
    tong_don.append(j)
print(tong_don)
sl_don = len(tong_don)
for i in tong_don:
    tong_don_1.append(i[0][0])
print(tong_don_1)
# Out:
# [['548.9715'], ['80.22'], ['340.5255'], ['489.048'], ['634.3785'], ['627.6165'], ['433.692'], ['772.38'], ['76.146'], ['172.746'], ['60.816'], ['107.142'], ['246.4875'], ['453.495'], ['749.49'], ['590.436'], ['506.6355'], ['457.443'], ['172.2105'], ['84.63'], ['451.71'], ['277.137'], ['69.72'], ['181.44'], ['279.1845'], ['441.756'], ['35.196'], ['184.107'], ['463.89'], ['235.2105'], ['494.1825'], ['737.7615'], ['703.752'], ['202.818'], ['417.564'], ['71.526'], ['328.755'], ['575.316'], ['461.328'], ['253.008'], ['91.056'], ['117.831'], ['435.456'], ['829.08'], ['32.277'], ['394.632'], ['535.7205'], ['189.0945'], ['119.259'], ['867.615'], ['671.79'], ['234.0975'], ['75.054'], ['16.2015'], ['33.936'], ['722.232'], ['93.114'], ['752.64'], ['759.675'], ['192.843'], ['77.931'], ['351.099'], ['520.4115'], ['166.005'], ['318.108'], ['166.635'], ['70.287'], ['614.943'], ['827.085'], ['19.2465'], ['939.54'], ['652.26'], ['152.838'], ['478.233'], ['705.6315'], ['437.325'], ['463.428'], ['189.0
# ...
